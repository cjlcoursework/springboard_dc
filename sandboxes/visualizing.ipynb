# %% [markdown]
# # Visualizing data
#
# ### Links:
# ---
#
# [Jake VanderPlas on Visual Tools](https://www.youtube.com/watch?v=FytuB8nFHPQ)
#
# <p>
#
# ### Concepts:
# ---
# - matplotlib cluster -
# - javascript cluster - plotly and bokeh,
#     - what about d3 - d3.js - vega, Altair (python)
# - OpenGL cluster - Glumpy, Vispy

# %% [markdown]
# ---
# # matplotlib cluster

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# using the attribute information as the column names
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']
iris =  pd.read_csv(csv_url, names = col_names)
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.scatter('Petal_Length', 'Petal_Width')
# Out:
# <AxesSubplot:xlabel='Petal_Length', ylabel='Petal_Width'>

# %%
from pandas.plotting import andrews_curves as ac
ac(iris, 'Class')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

sns.pairplot(iris, hue='Class')

# %% [markdown]
# # d3graph

# %%
from d3graph import d3graph, vec2adjmat
# Create example network
source = ['node A','node F','node B','node B','node B','node A','node C','node Z']
target = ['node F','node B','node J','node F','node F','node M','node M','node A']
weight = [5.56, 0.5, 0.64, 0.23, 0.9, 3.28, 0.5, 0.45]
# Convert to adjacency matrix
adjmat = vec2adjmat(source, target, weight=weight)

# Initialize
d3 = d3graph()
# Proces adjmat
d3.graph(adjmat)
# Plot
d3.show()
# Out:
# [d3graph] INFO> Set directed=True to see the markers!
# [d3graph] INFO> Keep only edges with weight>0
# [d3graph] INFO> Number of unique nodes: 7
# [d3graph] INFO> Slider range is set to [0, 6]
# [d3graph] INFO> Write to path: [/var/folders/c2/xznlms511f5_7k456wbrkk000000gn/T/tmper7oe22i/d3graph.html]
# [d3graph] INFO> File already exists and will be overwritten: [/var/folders/c2/xznlms511f5_7k456wbrkk000000gn/T/tmper7oe22i/d3graph.html]

# %% [markdown]
# # Bokeh

# %%
from bokeh.plotting import figure, show
# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="Simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness to the plot
p.line(x, y, legend_label="Temp.", line_width=2)

show(p)

# %% [markdown]
# ---
#
# # OpenGL based - big data
# - Glumpy
# - Vispy

# %%
# TBD

# %% [markdown]
# # Datashader (check this out)

# %%
# TBD

# %% [markdown]
# # Holoviews
#
# - Higher level wrapper for Bokeh, D3, etc
#
# - [Geovisualization using Holoviews and Python](https://towardsdatascience.com/the-battle-of-interactive-geographic-visualization-part-1-interactive-geoplot-using-one-line-of-8214e9ed1bb4)
# ---

# %%
# TBD

# %% [markdown]
# # Altair
#
# - Declarative
# - Higher level wrapper for Bokeh, D3, Datashader
# - Sits on Vega
#
# - [Altair and Python](https://towardsdatascience.com/the-battle-of-interactive-geographic-visualization-part-4-altair-5b67e3e5e29e)

# %%
import altair as alt

# load a simple dataset as a pandas DataFrame
from vega_datasets import data
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
).interactive()
# Out:
# alt.Chart(...)
